# %%
# !pip install newspaper3k
from newspaper import Article

url = 'https://optimism.mirror.xyz/dnl3dh7PgyNRigjaMvBoaQlOCuL5FXICqLyi8gyGxac'
article = Article(url)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
article.download()

article.html
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><style>body {\n          --accent: var(--mode-colors-accent);\n          --accentText: var(--mode-colors-accentText);\n          --background: var(--mode-colors-background);\n          --backgroundSecondary: var(--mode-colors-backgroundSecondary);\n          --backgroundTertiary: var(--mode-colors-backgroundTertiary);\n          --foreground: var(--mode-colors-foreground);\n          --groupBackground: var(--mode-colors-groupBackground);\n          --groupBorder: var(--mode-colors-groupBorder);\n          --relativeBackground: var(--mode-colors-background);\n\n          --blue: var(--mode-colors-blue);\n          --green: var(--mode-colors-green);\n          --indigo: var(--mode-colors-indigo);\n          --orange: var(--mode-colors-orange);\n          --pink: var(--mode-colors-pink);\n          --purple: var(--mode-colors-purple);\n          --red: var(--mode-colors-red);\n        
# ...

# %%
article.parse()

article.authors
article.publish_date
article.text
# Out:
# "The Optimism Collective is building community governance through experimentation. This iteration happens through time-bound governance experiments known as “Seasons.” Seasons allow the Collective to test new strategies for incrementally increasing community involvement in the governance of the Optimism Collective, while incorporating reflection and feedback as fundamental stages of the process.\n\nThis approach is informed by ongoing research into the challenges and successes of other DAOs.\n\nOngoing analysis of DAO design\n\nThe Optimism Foundation has prioritized research into various aspects of the historical development and processes of DAOs. The design of Season 4 - and the Collective’s approach generally - speaks to a few concepts in particular, such as: adopting multiple decision-making models, creating prioritization frameworks to guide strategy, and ensuring funding structures are flexible.\n\nThe full results of this research were compiled by Optimism Foundation Governanc
# ...

# %%
article.top_image
article.movies

# %%
import nltk
nltk.download('punkt')
article.nlp()
article.keywords
article.summary
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 'The Optimism Collective is building community governance through experimentation.\nIf you’re interested, check out DAO governance timelines here and search the governance library here.\nThis openness fosters innovation and allows us to iterate quickly on DAO governance, a challenge faced by both DAOs and governments outside of crypto.\nSeason 4: laying the groundwork for more community involvementIn Season 4, the Collective will run several key experiments designed to increase community involvement in the gradual decentralization of Optimism.\nFor a full guide to Season 4 and to see community discussion about these experiments, visit the Collective’s governance forum.'
